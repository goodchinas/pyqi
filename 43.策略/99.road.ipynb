# %%
from graphviz import Digraph

# %%
ps = Digraph(name='pet-shop', node_attr={'shape': 'plaintext'})

ps.node('parrot')
ps.node('dead')
ps.edge('parrot', 'dead')

ps.graph_attr['rankdir'] = 'LR'
ps.edge_attr.update(arrowhead='vee', arrowsize='3')
ps

# %% [markdown]
# # god
# 1. 要学的知识和要解决的疑问还有很多啊
# 2. 要做的事情还有很多啊
# 3. 否定之否定阶段到来，自我怀疑时刻

# %% [markdown]
# ## 关键链接逻辑
# 1. 金融投资的定量研究--------------风险和收益的定义问题
# 2. 收益可加性和风险分散性----------组合优化及mpt
# 3. 组合投资+分离定理---------------市场组合M
# 4. 组合优化+期望收益估计-----------capm资产定价---beta
# 4. apt----理论的困境-----实证的说服力
#     1. [什么是多因子定价模型？APT（套利定价理论）、Fama-French三因子模型之间的关系是怎样的？](https://www.zhihu.com/question/51147196/answer/126812444)
# 5. [资产定价的在统计上足够接近零--股票多因子模型的回归检验](https://zhuanlan.zhihu.com/p/40984029)
#     1. [Which Beta ?](https://zhuanlan.zhihu.com/p/71072376)
#     2. [Which Beta (II) ?](https://zhuanlan.zhihu.com/p/84462587)
# 6. 规程-----[实证研究 —— 使用正交化和自助法寻找显著因子](https://zhuanlan.zhihu.com/p/59861534)
# 7. fama三因子--因子选股---因子收益率-----因子载荷暴漏
# 8. 时序回归-----截面回归
# 9.    ------------------组合投资-----资产配置
# 9.                      bl
# 10.   ------------------barra
# 11.  1. 求市值权重、风险平价权重、最大因子暴漏（可投资性和因子性）等配置的barra风险

# %% [markdown]
# ## road
# 0. 因子值标准化
# 3. barra风险分析
# 4. brinson绩效归因分析
# 3. 因子暴漏值和下一期截面回归求因子收益序列
